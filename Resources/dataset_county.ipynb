# %%
import pandas as pd
from sqlalchemy import create_engine
import datetime

# %%
cases_file = "/Users/mquinton/Desktop/ETL-Project-Group5/Resources/cases.csv"
cases_df = pd.read_csv(cases_file)
cases_df.head()
# Out:
#      state        date  total_population  cumulative_cases  \
# 0  Alabama  2020-01-22         4887871.0                 0
# 1  Alabama  2020-01-23         4887871.0                 0
# 2  Alabama  2020-01-24         4887871.0                 0
# 3  Alabama  2020-01-25         4887871.0                 0
# 4  Alabama  2020-01-26         4887871.0                 0
#
#    cumulative_cases_per_100_000  cumulative_deaths  \
# 0                           0.0                  0
# 1                           0.0                  0
# 2                           0.0                  0
# 3                           0.0                  0
# 4                           0.0                  0
#
#    cumulative_deaths_per_100_000  new_cases  new_cases_7_day_rolling_avg  \
# 0                            0.0        NaN                          NaN
# 1                            0.0        0.0                          NaN
# 2                            0.0        0.0                          NaN
# ...

# %% [markdown]
# - We chose this dataset to work further with by county data in Indiana

# %%
# New dataframe with only IN data
IN_cases_df = cases_df.loc[cases_df['state'] == 'Indiana']
IN_cases_df
# Out:
#         state        date  total_population  cumulative_cases  \
# 5088  Indiana  2020-01-22         6691878.0                 0
# 5089  Indiana  2020-01-23         6691878.0                 0
# 5090  Indiana  2020-01-24         6691878.0                 0
# 5091  Indiana  2020-01-25         6691878.0                 0
# 5092  Indiana  2020-01-26         6691878.0                 0
# ...       ...         ...               ...               ...
# 5401  Indiana  2020-11-30         6691878.0            338977
# 5402  Indiana  2020-12-01         6691878.0            344373
# 5403  Indiana  2020-12-02         6691878.0            350970
# 5404  Indiana  2020-12-03         6691878.0            359430
# 5405  Indiana  2020-12-04         6691878.0            367329
#
#       cumulative_cases_per_100_000  cumulative_deaths  \
# 5088                          0.00                  0
# 5089                          0.00                  0
# 5090                          0.00                  0
# ...

# %%
IN_cases_df = IN_county_df.rename(columns={'date': 'Date',
                          'total_population': 'Population',
                          'cumulative_cases': 'total_cases',
                          'cumulative_cases_per_100_000': 'total_cases_per_100000',
                          'cumulative_deaths': 'total_deaths',
                          'cumulative_deaths_per_100_000': 'total_cases_per_100000'
                         })
IN_cases_df
# Out:
#         State        Date  Population  total_cases  total_cases_per_100000  \
# 5088  Indiana  2020-01-22   6691878.0            0                    0.00
# 5089  Indiana  2020-01-23   6691878.0            0                    0.00
# 5090  Indiana  2020-01-24   6691878.0            0                    0.00
# 5091  Indiana  2020-01-25   6691878.0            0                    0.00
# 5092  Indiana  2020-01-26   6691878.0            0                    0.00
# ...       ...         ...         ...          ...                     ...
# 5401  Indiana  2020-11-30   6691878.0       338977                 5065.50
# 5402  Indiana  2020-12-01   6691878.0       344373                 5146.13
# 5403  Indiana  2020-12-02   6691878.0       350970                 5244.72
# 5404  Indiana  2020-12-03   6691878.0       359430                 5371.14
# 5405  Indiana  2020-12-04   6691878.0       367329                 5489.18
#
#       total_deaths  total_cases_per_100000  new_cases  \
# ...

# %%
# Drop columns we do not need
IN_cases_df.drop(columns=['new_cases_7_day_rolling_avg', 'new_deaths_7_day_rolling_avg'])
# Out:
#         State        Date  Population  total_cases  total_cases_per_100000  \
# 5088  Indiana  2020-01-22   6691878.0            0                    0.00
# 5089  Indiana  2020-01-23   6691878.0            0                    0.00
# 5090  Indiana  2020-01-24   6691878.0            0                    0.00
# 5091  Indiana  2020-01-25   6691878.0            0                    0.00
# 5092  Indiana  2020-01-26   6691878.0            0                    0.00
# ...       ...         ...         ...          ...                     ...
# 5401  Indiana  2020-11-30   6691878.0       338977                 5065.50
# 5402  Indiana  2020-12-01   6691878.0       344373                 5146.13
# 5403  Indiana  2020-12-02   6691878.0       350970                 5244.72
# 5404  Indiana  2020-12-03   6691878.0       359430                 5371.14
# 5405  Indiana  2020-12-04   6691878.0       367329                 5489.18
#
#       total_deaths  total_cases_per_100000  new_cases  new_deaths  \
# ...

# %%
IN_cases_df['Date'] = pd.to_datetime(IN_cases_df['Date'], format='%Y%m%d', infer_datetime_format=True)

# %%
IN_cases_df.set_index('Date')
# Out:
#               State  Population  total_cases  total_cases_per_100000  \
# Date
# 2020-01-22  Indiana   6691878.0            0                    0.00
# 2020-01-23  Indiana   6691878.0            0                    0.00
# 2020-01-24  Indiana   6691878.0            0                    0.00
# 2020-01-25  Indiana   6691878.0            0                    0.00
# 2020-01-26  Indiana   6691878.0            0                    0.00
# ...             ...         ...          ...                     ...
# 2020-11-30  Indiana   6691878.0       338977                 5065.50
# 2020-12-01  Indiana   6691878.0       344373                 5146.13
# 2020-12-02  Indiana   6691878.0       350970                 5244.72
# 2020-12-03  Indiana   6691878.0       359430                 5371.14
# 2020-12-04  Indiana   6691878.0       367329                 5489.18
#
#             total_deaths  total_cases_per_100000  new_cases  \
# Date
# 2020-01-22             0                    0.00        NaN
# ...
