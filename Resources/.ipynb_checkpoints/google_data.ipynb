# %%
import pandas as pd
import os

# %%
df = pd.read_csv("2020_US_Region_Mobility_Report.csv")
df
# Out:
#        country_region_code country_region sub_region_1   sub_region_2  \
# 0                       US  United States          NaN            NaN
# 1                       US  United States          NaN            NaN
# 2                       US  United States          NaN            NaN
# 3                       US  United States          NaN            NaN
# 4                       US  United States          NaN            NaN
# ...                    ...            ...          ...            ...
# 727714                  US  United States      Wyoming  Weston County
# 727715                  US  United States      Wyoming  Weston County
# 727716                  US  United States      Wyoming  Weston County
# 727717                  US  United States      Wyoming  Weston County
# 727718                  US  United States      Wyoming  Weston County
#
#         metro_area iso_3166_2_code  census_fips_code        date  \
# ...

# %%
clean_df = df.rename(columns={"country_region_code": "Country Code",
                             "country_region": "Country",
                             "sub_region_1": "State",
                             "sub_region_2": "County",
                             "metro_area": "Metro Area",
                             "iso_3166_2_code": "Territory Subdivisions",
                             "census_fips_code": "Census FIPS Codes",
                             "date": "Date",
                             "retail_and_recreation_percent_change_from_baseline": "Retail & Recreation Percent Change from Baseline",
                             "grocery_and_pharmacy_percent_change_from_baseline": "Grocery & Pharmacy Percent Change from Baseline",
                             "parks_percent_change_from_baseline": "Parks Percent Change from Baseline",
                             "transit_stations_percent_change_from_baseline": "Transit Stations Percent Change from Baseline",
                             "workplaces_percent_change_from_baseline": "Workplaces Percent Change from Baseline",
                             "residential_percent_change_from_baseline": "Residential Percent Change from Baseline",})
clean_df.head()
# Out:
#   Country Code        Country State County  Metro Area Territory Subdivisions  \
# 0           US  United States   NaN    NaN         NaN                    NaN
# 1           US  United States   NaN    NaN         NaN                    NaN
# 2           US  United States   NaN    NaN         NaN                    NaN
# 3           US  United States   NaN    NaN         NaN                    NaN
# 4           US  United States   NaN    NaN         NaN                    NaN
#
#    Census FIPS Codes        Date  \
# 0                NaN  2020-02-15
# 1                NaN  2020-02-16
# 2                NaN  2020-02-17
# 3                NaN  2020-02-18
# 4                NaN  2020-02-19
#
#    Retail & Recreation Percent Change from Baseline  \
# 0                                               6.0
# 1                                               7.0
# 2                                               6.0
# 3                                               0.0
# ...
