# %%
import pandas as pd
import os

# %%
df = pd.read_csv("2020_US_Region_Mobility_Report.csv")
df
# Out:
#        country_region_code country_region sub_region_1   sub_region_2  \
# 0                       US  United States          NaN            NaN
# 1                       US  United States          NaN            NaN
# 2                       US  United States          NaN            NaN
# 3                       US  United States          NaN            NaN
# 4                       US  United States          NaN            NaN
# ...                    ...            ...          ...            ...
# 727714                  US  United States      Wyoming  Weston County
# 727715                  US  United States      Wyoming  Weston County
# 727716                  US  United States      Wyoming  Weston County
# 727717                  US  United States      Wyoming  Weston County
# 727718                  US  United States      Wyoming  Weston County
#
#         metro_area iso_3166_2_code  census_fips_code        date  \
# 0              NaN             NaN               NaN  2020-02-15
# 1              NaN             NaN               NaN  2020-02-16
# 2              NaN             NaN               NaN  2020-02-17
# 3              NaN             NaN               NaN  2020-02-18
# 4              NaN             NaN               NaN  2020-02-19
# ...            ...             ...               ...         ...
# 727714         NaN             NaN           56045.0  2020-11-23
# 727715         NaN             NaN           56045.0  2020-11-24
# 727716         NaN             NaN           56045.0  2020-11-25
# 727717         NaN             NaN           56045.0  2020-11-26
# 727718         NaN             NaN           56045.0  2020-11-27
#
#         retail_and_recreation_percent_change_from_baseline  \
# 0                                                     6.0
# 1                                                     7.0
# 2                                                     6.0
# 3                                                     0.0
# 4                                                     2.0
# ...                                                   ...
# 727714                                                NaN
# 727715                                                NaN
# 727716                                                NaN
# 727717                                                NaN
# 727718                                                NaN
#
#         grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                     2.0
# 1                                                     1.0
# 2                                                     0.0
# 3                                                    -1.0
# 4                                                     0.0
# ...                                                   ...
# 727714                                                NaN
# 727715                                                NaN
# 727716                                                NaN
# 727717                                                NaN
# 727718                                                NaN
#
#         parks_percent_change_from_baseline  \
# 0                                     15.0
# 1                                     16.0
# 2                                     28.0
# 3                                      6.0
# 4                                      8.0
# ...                                    ...
# 727714                                 NaN
# 727715                                 NaN
# 727716                                 NaN
# 727717                                 NaN
# 727718                                 NaN
#
#         transit_stations_percent_change_from_baseline  \
# 0                                                 3.0
# 1                                                 2.0
# 2                                                -9.0
# 3                                                 1.0
# 4                                                 1.0
# ...                                               ...
# 727714                                            NaN
# 727715                                            NaN
# 727716                                            NaN
# 727717                                            NaN
# 727718                                            NaN
#
#         workplaces_percent_change_from_baseline  \
# 0                                           2.0
# 1                                           0.0
# 2                                         -24.0
# 3                                           0.0
# 4                                           1.0
# ...                                         ...
# 727714                                    -23.0
# 727715                                    -21.0
# 727716                                    -27.0
# 727717                                    -73.0
# 727718                                    -58.0
#
#         residential_percent_change_from_baseline
# 0                                           -1.0
# 1                                           -1.0
# 2                                            5.0
# 3                                            1.0
# 4                                            0.0
# ...                                          ...
# 727714                                       NaN
# 727715                                       NaN
# 727716                                       NaN
# 727717                                       NaN
# 727718                                       NaN
#
# [727719 rows x 14 columns]

# %%
clean_df = df.rename(columns={"country_region_code": "country_code",
                             "country_region": "country",
                             "sub_region_1": "state",
                             "sub_region_2": "county",
                             "metro_area": "metro_area",
                             "iso_3166_2_code": "territory_subdivisions",
                             "census_fips_code": "census_fips_code",
                             "date": "date",
                             "retail_and_recreation_percent_change_from_baseline": "retail_and_recreation_percent_change_from_baseline",
                             "grocery_and_pharmacy_percent_change_from_baseline": "grocery_and_pharmacy_percent_change_from_baseline",
                             "parks_percent_change_from_baseline": "parks_percent_change_from_baseline",
                             "transit_stations_percent_change_from_baseline": "transit_stations_percent_change_from_baseline",
                             "workplaces_percent_change_from_baseline": "workplaces_percent_change_from_baseline",
                             "residential_percent_change_from_baseline": "residential_percent_change_from_baseline",})
clean_df.head()
# Out:
#   country_code        country state county  metro_area territory_subdivisions  \
# 0           US  United States   NaN    NaN         NaN                    NaN
# 1           US  United States   NaN    NaN         NaN                    NaN
# 2           US  United States   NaN    NaN         NaN                    NaN
# 3           US  United States   NaN    NaN         NaN                    NaN
# 4           US  United States   NaN    NaN         NaN                    NaN
#
#    census_fips_code        date  \
# 0               NaN  2020-02-15
# 1               NaN  2020-02-16
# 2               NaN  2020-02-17
# 3               NaN  2020-02-18
# 4               NaN  2020-02-19
#
#    retail_and_recreation_percent_change_from_baseline  \
# 0                                                6.0
# 1                                                7.0
# 2                                                6.0
# 3                                                0.0
# 4                                                2.0
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                2.0
# 1                                                1.0
# 2                                                0.0
# 3                                               -1.0
# 4                                                0.0
#
#    parks_percent_change_from_baseline  \
# 0                                15.0
# 1                                16.0
# 2                                28.0
# 3                                 6.0
# 4                                 8.0
#
#    transit_stations_percent_change_from_baseline  \
# 0                                            3.0
# 1                                            2.0
# 2                                           -9.0
# 3                                            1.0
# 4                                            1.0
#
#    workplaces_percent_change_from_baseline  \
# 0                                      2.0
# 1                                      0.0
# 2                                    -24.0
# 3                                      0.0
# 4                                      1.0
#
#    residential_percent_change_from_baseline
# 0                                      -1.0
# 1                                      -1.0
# 2                                       5.0
# 3                                       1.0
# 4                                       0.0

# %%
clean_df = clean_df[[
    "state",
    "county",
    "date",
    "retail_and_recreation_percent_change_from_baseline",
    "grocery_and_pharmacy_percent_change_from_baseline",
    "parks_percent_change_from_baseline",
    "transit_stations_percent_change_from_baseline",
    "workplaces_percent_change_from_baseline",
    "residential_percent_change_from_baseline"
]]
clean_df.head()
# Out:
#   state county        date  \
# 0   NaN    NaN  2020-02-15
# 1   NaN    NaN  2020-02-16
# 2   NaN    NaN  2020-02-17
# 3   NaN    NaN  2020-02-18
# 4   NaN    NaN  2020-02-19
#
#    retail_and_recreation_percent_change_from_baseline  \
# 0                                                6.0
# 1                                                7.0
# 2                                                6.0
# 3                                                0.0
# 4                                                2.0
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                2.0
# 1                                                1.0
# 2                                                0.0
# 3                                               -1.0
# 4                                                0.0
#
#    parks_percent_change_from_baseline  \
# 0                                15.0
# 1                                16.0
# 2                                28.0
# 3                                 6.0
# 4                                 8.0
#
#    transit_stations_percent_change_from_baseline  \
# 0                                            3.0
# 1                                            2.0
# 2                                           -9.0
# 3                                            1.0
# 4                                            1.0
#
#    workplaces_percent_change_from_baseline  \
# 0                                      2.0
# 1                                      0.0
# 2                                    -24.0
# 3                                      0.0
# 4                                      1.0
#
#    residential_percent_change_from_baseline
# 0                                      -1.0
# 1                                      -1.0
# 2                                       5.0
# 3                                       1.0
# 4                                       0.0

# %%
clean_df = clean_df.dropna(subset=['state'])
clean_df
# Out:
#           state         county        date  \
# 289     Alabama            NaN  2020-02-15
# 290     Alabama            NaN  2020-02-16
# 291     Alabama            NaN  2020-02-17
# 292     Alabama            NaN  2020-02-18
# 293     Alabama            NaN  2020-02-19
# ...         ...            ...         ...
# 727714  Wyoming  Weston County  2020-11-23
# 727715  Wyoming  Weston County  2020-11-24
# 727716  Wyoming  Weston County  2020-11-25
# 727717  Wyoming  Weston County  2020-11-26
# 727718  Wyoming  Weston County  2020-11-27
#
#         retail_and_recreation_percent_change_from_baseline  \
# 289                                                   5.0
# 290                                                   0.0
# 291                                                   3.0
# 292                                                  -4.0
# 293                                                   4.0
# ...                                                   ...
# 727714                                                NaN
# 727715                                                NaN
# 727716                                                NaN
# 727717                                                NaN
# 727718                                                NaN
#
#         grocery_and_pharmacy_percent_change_from_baseline  \
# 289                                                   2.0
# 290                                                  -2.0
# 291                                                   0.0
# 292                                                  -3.0
# 293                                                   1.0
# ...                                                   ...
# 727714                                                NaN
# 727715                                                NaN
# 727716                                                NaN
# 727717                                                NaN
# 727718                                                NaN
#
#         parks_percent_change_from_baseline  \
# 289                                   39.0
# 290                                   -7.0
# 291                                   17.0
# 292                                  -11.0
# 293                                    6.0
# ...                                    ...
# 727714                                 NaN
# 727715                                 NaN
# 727716                                 NaN
# 727717                                 NaN
# 727718                                 NaN
#
#         transit_stations_percent_change_from_baseline  \
# 289                                               7.0
# 290                                               3.0
# 291                                               7.0
# 292                                              -1.0
# 293                                               4.0
# ...                                               ...
# 727714                                            NaN
# 727715                                            NaN
# 727716                                            NaN
# 727717                                            NaN
# 727718                                            NaN
#
#         workplaces_percent_change_from_baseline  \
# 289                                         2.0
# 290                                        -1.0
# 291                                       -17.0
# 292                                         1.0
# 293                                         1.0
# ...                                         ...
# 727714                                    -23.0
# 727715                                    -21.0
# 727716                                    -27.0
# 727717                                    -73.0
# 727718                                    -58.0
#
#         residential_percent_change_from_baseline
# 289                                         -1.0
# 290                                          1.0
# 291                                          4.0
# 292                                          2.0
# 293                                          0.0
# ...                                          ...
# 727714                                       NaN
# 727715                                       NaN
# 727716                                       NaN
# 727717                                       NaN
# 727718                                       NaN
#
# [727430 rows x 9 columns]

# %%
indiana_df = clean_df[clean_df['state'] == "Indiana"]
indiana_df
# Out:
#           state          county        date  \
# 167818  Indiana             NaN  2020-02-15
# 167819  Indiana             NaN  2020-02-16
# 167820  Indiana             NaN  2020-02-17
# 167821  Indiana             NaN  2020-02-18
# 167822  Indiana             NaN  2020-02-19
# ...         ...             ...         ...
# 192824  Indiana  Whitley County  2020-11-25
# 192825  Indiana  Whitley County  2020-11-26
# 192826  Indiana  Whitley County  2020-11-27
# 192827  Indiana  Whitley County  2020-11-28
# 192828  Indiana  Whitley County  2020-11-29
#
#         retail_and_recreation_percent_change_from_baseline  \
# 167818                                                9.0
# 167819                                                8.0
# 167820                                                5.0
# 167821                                                1.0
# 167822                                                4.0
# ...                                                   ...
# 192824                                               18.0
# 192825                                              -68.0
# 192826                                              -18.0
# 192827                                              -10.0
# 192828                                              -11.0
#
#         grocery_and_pharmacy_percent_change_from_baseline  \
# 167818                                                4.0
# 167819                                                3.0
# 167820                                               -3.0
# 167821                                               -1.0
# 167822                                                0.0
# ...                                                   ...
# 192824                                               36.0
# 192825                                                NaN
# 192826                                              -15.0
# 192827                                                NaN
# 192828                                               -2.0
#
#         parks_percent_change_from_baseline  \
# 167818                                16.0
# 167819                                34.0
# 167820                                -4.0
# 167821                                 3.0
# 167822                                 9.0
# ...                                    ...
# 192824                                 NaN
# 192825                                 NaN
# 192826                                 NaN
# 192827                                 NaN
# 192828                                 NaN
#
#         transit_stations_percent_change_from_baseline  \
# 167818                                            7.0
# 167819                                            5.0
# 167820                                            2.0
# 167821                                            4.0
# 167822                                            5.0
# ...                                               ...
# 192824                                            NaN
# 192825                                            NaN
# 192826                                            NaN
# 192827                                            NaN
# 192828                                            NaN
#
#         workplaces_percent_change_from_baseline  \
# 167818                                      0.0
# 167819                                      1.0
# 167820                                    -13.0
# 167821                                      2.0
# 167822                                      2.0
# ...                                         ...
# 192824                                    -35.0
# 192825                                    -87.0
# 192826                                    -69.0
# 192827                                    -25.0
# 192828                                    -13.0
#
#         residential_percent_change_from_baseline
# 167818                                      -1.0
# 167819                                      -1.0
# 167820                                       4.0
# 167821                                       0.0
# 167822                                       0.0
# ...                                          ...
# 192824                                      10.0
# 192825                                      27.0
# 192826                                      22.0
# 192827                                       NaN
# 192828                                       NaN
#
# [25011 rows x 9 columns]

# %%
indiana_df = indiana_df.dropna(subset=['county'])

# %%
indiana_df = indiana_df.reset_index(drop=True)

# %%
indiana_df
# Out:
#          state          county        date  \
# 0      Indiana    Adams County  2020-02-15
# 1      Indiana    Adams County  2020-02-16
# 2      Indiana    Adams County  2020-02-17
# 3      Indiana    Adams County  2020-02-18
# 4      Indiana    Adams County  2020-02-19
# ...        ...             ...         ...
# 24717  Indiana  Whitley County  2020-11-25
# 24718  Indiana  Whitley County  2020-11-26
# 24719  Indiana  Whitley County  2020-11-27
# 24720  Indiana  Whitley County  2020-11-28
# 24721  Indiana  Whitley County  2020-11-29
#
#        retail_and_recreation_percent_change_from_baseline  \
# 0                                                    5.0
# 1                                                    7.0
# 2                                                    3.0
# 3                                                    7.0
# 4                                                    4.0
# ...                                                  ...
# 24717                                               18.0
# 24718                                              -68.0
# 24719                                              -18.0
# 24720                                              -10.0
# 24721                                              -11.0
#
#        grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                  -11.0
# 1                                                    NaN
# 2                                                  -10.0
# 3                                                   -7.0
# 4                                                   -6.0
# ...                                                  ...
# 24717                                               36.0
# 24718                                                NaN
# 24719                                              -15.0
# 24720                                                NaN
# 24721                                               -2.0
#
#        parks_percent_change_from_baseline  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ...                                   ...
# 24717                                 NaN
# 24718                                 NaN
# 24719                                 NaN
# 24720                                 NaN
# 24721                                 NaN
#
#        transit_stations_percent_change_from_baseline  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 24717                                            NaN
# 24718                                            NaN
# 24719                                            NaN
# 24720                                            NaN
# 24721                                            NaN
#
#        workplaces_percent_change_from_baseline  \
# 0                                          2.0
# 1                                          1.0
# 2                                         -5.0
# 3                                          1.0
# 4                                          2.0
# ...                                        ...
# 24717                                    -35.0
# 24718                                    -87.0
# 24719                                    -69.0
# 24720                                    -25.0
# 24721                                    -13.0
#
#        residential_percent_change_from_baseline
# 0                                           NaN
# 1                                           NaN
# 2                                           3.0
# 3                                           0.0
# 4                                           0.0
# ...                                         ...
# 24717                                      10.0
# 24718                                      27.0
# 24719                                      22.0
# 24720                                       NaN
# 24721                                       NaN
#
# [24722 rows x 9 columns]

# %%
indiana_df2 = indiana_df.dropna(how='any')
